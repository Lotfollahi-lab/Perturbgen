# %%
# !pip install mygene
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting mygene
#   Downloading mygene-3.2.2-py2.py3-none-any.whl.metadata (10 kB)
# Collecting biothings-client>=0.2.6 (from mygene)
#   Downloading biothings_client-0.3.1-py2.py3-none-any.whl.metadata (9.8 kB)
# Requirement already satisfied: requests>=2.3.0 in /software/isg/languages/Python/Python-3.11.10-jupyter/exec/lib/python3.11/site-packages (from biothings-client>=0.2.6->mygene) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /software/isg/languages/Python/Python-3.11.10-jupyter/exec/lib/python3.11/site-packages (from requests>=2.3.0->biothings-client>=0.2.6->mygene) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /software/isg/languages/Python/Python-3.11.10-jupyter/exec/lib/python3.11/site-packages (from requests>=2.3.0->biothings-client>=0.2.6->mygene) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /software/isg/languages/Python/Python-3.11.10-jupyter/exec/lib/python3.11/site-packages (from requests>=2.3.0->biothings-client>=0.2.6->mygene) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /software/isg/languages/Python/Python-3.11.10-jupyter/exec/lib/python3.11/site-packages (from requests>=2.3.0->biothings-client>=0.2.6->mygene) (2023.7.22)
# Downloading mygene-3.2.2-py2.py3-none-any.whl (5.4 kB)
# Downloading biothings_client-0.3.1-py2.py3-none-any.whl (29 kB)
# Installing collected packages: biothings-client, mygene
# Successfully installed biothings-client-0.3.1 mygene-3.2.2
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python3 -m pip install --upgrade pip

# %%
import mygene

def get_symbol_to_ensembl_mapping(gene_symbols):
    mg = mygene.MyGeneInfo()
    # Query MyGene.info to get Ensembl IDs
    query_results = mg.querymany(gene_symbols, scopes='symbol', fields='ensembl.gene', species='human')
    symbol_to_ensembl = {}
    for entry in query_results:
        symbol = entry['query']
        ensembl_ids = []
        if 'ensembl' in entry:
            ensembl = entry['ensembl']
            if isinstance(ensembl, list):
                ensembl_ids = [item['gene'] for item in ensembl if 'gene' in item]
            elif isinstance(ensembl, dict) and 'gene' in ensembl:
                ensembl_ids = [ensembl['gene']]
        symbol_to_ensembl[symbol] = ensembl_ids
    return symbol_to_ensembl

# Assuming you have your tokenid_to_genename_dict loaded
gene_symbols = list(['TTLL6', 'TLR4', 'CTNNB1', 'TP53INP1', 'CLU'])
symbol_to_ensembl = get_symbol_to_ensembl_mapping(gene_symbols)
print(symbol_to_ensembl)
# Out:
# {'TTLL6': ['ENSG00000170703'], 'TLR4': ['ENSG00000136869'], 'CTNNB1': ['ENSG00000168036'], 'TP53INP1': ['ENSG00000164938'], 'CLU': ['ENSG00000120885']}
